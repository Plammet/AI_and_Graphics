# %% [markdown]
# ### 2021-2 Machine Learning (01)
# ## Homework #3-1: K-Means Clustering
# ---
# Copyright (c) Code Designed by Prof. Jaehyeong Sim
#
# Department of Computer Science and Engineering
#
# Ewha Womans University

# %% [markdown]
# ## Prepare input data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go

D = 3
K = 5

all_color = ["blue", "green", "red", "yellow", "magenta", "cyan", "black"]
color = all_color[:K]

X, t = make_blobs(n_features=D, centers=K, random_state=3, cluster_std=1)
N = len(X)

# %% [markdown]
# ## Visualize the data in 3d space

# %%
df = pd.DataFrame(X, columns=["x1", "x2", "x3"])
fig = go.Figure(data=[go.Scatter3d(x=df.x1, y=df.x2, z=df.x3, mode='markers', marker_size=2, marker_color="black")])
fig.update_coloraxes(showscale=False)
fig.update_layout(legend_itemsizing="constant")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7758c151-5c0a-43d7-a77e-f65f363003df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7758c151-5c0a-43d7-a77e-f65f363003df")) {
#                     Plotly.newPlot(
#                         '7758c151-5c0a-43d7-a77e-f65f363003df',
#                         [{"marker": {"color": "black", "size": 2}, "mode": "markers", "type": "scatter3d", "x": [0.8461791080215897, -0.797208050544177, -6.086084722747711, 1.5069962629841949, -2.197695636113214, -7.463839043814759, 4.83688964314703, 1.8619112068343855, 0.3184042357219269, -0.7168264075160402, -2.160456531321827, -8.013229114822966, 1.7430632004416344, -0.1192757817665181, -7.4903857341996885, 4.236031935167006, -9.84319902410069, 0.4458431573105308, -7.566960081441442, 0.026345872213112798, -1.2867857478619882, -0.6014868171574341, 4.658409021883598, 0.7969621777860925, -8.234858100827076, 3.303287345839145, -1.0688259996565228, 2.137327380320145, 4.896331089103916, -0.5955145400878095, 3.474309380017537, -0.6331600543564272, -1.321230349561325, -7.246479458977192, -6.194488781458651, -0.8733579452204776, 0.31111720020450995, 1.1019175818082363, 0.1456619471772736, -1.0081573922526892, 2.752643086084139, 2.7422047201276074, 1.6796016815423915, 0.5771512270184583, 1.4138439116160684, -1.837902218123699, -1.3396500677861156, 0.09328140315821998, 0.13967254548774746, -8.255758707379064, -1.4557392666103455, -1.858820049119649, -8.209441370479885, -7.001597161806602, 1.9820891012908644, 0.03003970920557586, 4.386092566465265, -0.03286537869706385, 0.5883481865896005, 2.8822900270598883, -1.3167372913391915, -1.7712815978318073, -8.284899644579578, 1.2772705548515888, -9.186986681503367, 0.6686278759002947, 0.7178179725044151, -0.3656201612329941, -1.336043731250171, -0.6573915459317887, 5.090682760787606, -0.9534030266384663, 0.9812334406713685, -1.4053099379009972, 2.9493516691475947, 0.4813278903770004, -1.4236901258936068, 3.1323978605198803, 1.5623596260973571, 1.2288437101775482, -10.357590317321957, -0.18731814249347645, -8.693087844553178, 0.3092424491113592, 1.3018358570731434, 3.48788403800295, 0.8184548521656576, 0.4551481818212849, -0.043947848743715046, 3.352957660798238, -0.017902274864744133, 0.10554303410967476, 0.6393819133081341, -1.0971367299416481, -7.614918651083226,
}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor":

# %% [markdown]
# ## Distance function

# %%
def distance(p1, p2):
  # TODO: fill here
  # We need to compare distance, not exact value, so sqrt is omitted

  return ((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

# %% [markdown]
# ## Assign function: assign a data point to closest cluster center

# %%
def assign(point, Mu, K):
  dist = np.zeros((K, 1))
  for k in range(0,K):
    dist[k] = distance(point, Mu[k])
  return np.argmin(dist.ravel())

# %% [markdown]
# ## Move function: change the cluster centers to the average of their assigned points

# %%
def move(data, Mu):
  if (data.size == 0):
    return Mu
  else:
    return np.average(data, axis=0)

# %% [markdown]
# ## Iteration

# %%
# TODO: fill here

C = np.zeros([N], int)
new_Mu = np.zeros(np.shape(Mu))
Mu_trace = np.copy([Mu])

while(1):

  for i in range (N):
    C[i] = assign(X[i], Mu, K)

  for i in range(K):
    data = np.reshape(X[np.where(C == i),:], [-1,3])
    new_Mu[i] = move(data, Mu[i])

  Mu_trace = np.append(Mu_trace, [new_Mu], axis = 0)

  if (np.all(Mu == new_Mu)): break
  Mu = new_Mu

# %% [markdown]
# ## Visualize final assignment and centers

# %%
color_assign = []
for i in range(0,N):
  color_assign.append(color[C[i]])
  
fig = go.Figure(data=[go.Scatter3d(x=df.x1, y=df.x2, z=df.x3, mode='markers', marker_size=2, marker_color=color_assign, opacity=0.4)])
fig.update_coloraxes(showscale=False)
fig.update_layout(legend_itemsizing="constant")
for i in range(K):
  fig.add_trace(go.Scatter3d(x=Mu_trace[:,i,0], y=Mu_trace[:,i,1], z=Mu_trace[:,i,2], marker_size=3, marker_color=color[i]))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d958312d-176a-4602-96db-4fe68a2ba32e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d958312d-176a-4602-96db-4fe68a2ba32e")) {
#                     Plotly.newPlot(
#                         'd958312d-176a-4602-96db-4fe68a2ba32e',
#                         [{"marker": {"color": ["yellow", "blue", "red", "green", "magenta", "red", "yellow", "blue", "blue", "blue", "magenta", "red", "yellow", "green", "red", "yellow", "red", "green", "red", "blue", "magenta", "magenta", "yellow", "blue", "red", "yellow", "magenta", "yellow", "yellow", "green", "blue", "green", "magenta", "red", "red", "green", "magenta", "green", "green", "magenta", "yellow", "yellow", "yellow", "green", "blue", "magenta", "magenta", "blue", "green", "red", "magenta", "green", "red", "red", "yellow", "blue", "yellow", "blue", "green", "yellow", "magenta", "magenta", "red", "blue", "red", "blue", "green", "magenta", "magenta", "magenta", "yellow", "magenta", "blue", "magenta", "yellow", "blue", "magenta", "yellow", "green", "green", "red", "blue", "red", "green", "blue", "yellow", "yellow", "blue", "green", "yellow", "green", "green", "bl